# %% [markdown]
# <a href="https://colab.research.google.com/github/mohansai279/cod_soft/blob/main/task_2_credit_card_fraud_detection_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing libaries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
# %matplotlib inline

# %%
train_data=pd.read_csv('/content/fraudTest.csv')
test_data=pd.read_csv('/content/fraudTest.csv')

# %%
# amt column is removed because of zero variance
train_data.drop(columns=['Unnamed: 0','first', 'last', 'street', 'city','trans_date_trans_time','trans_num','dob','amt'],inplace=True)
test_data.drop(columns=['Unnamed: 0','first', 'last', 'street', 'city','trans_date_trans_time','trans_num','dob','amt'],inplace=True)
train_data.head()
# Out:
#              cc_num                              merchant        category  \
# 0  2291163933867244                 fraud_Kirlin and Sons   personal_care
# 1  3573030041201292                  fraud_Sporer-Keebler   personal_care
# 2  3598215285024754  fraud_Swaniawski, Nitzsche and Welch  health_fitness
# 3  3591919803438423                     fraud_Haley Group        misc_pos
# 4  3526826139003047                 fraud_Johnston-Casper          travel
#
#   gender state      zip      lat      long  city_pop                     job  \
# 0      M    SC  29209.0  33.9659  -80.9355  333497.0     Mechanical engineer
# 1      F    UT  84002.0  40.3207 -110.4360     302.0  Sales professional, IT
# 2      F    NY  11710.0  40.6729  -73.5365   34496.0       Librarian, public
# 3      M    FL  32780.0  28.5697  -80.8191   54767.0            Set designer
# 4      M    MI  49632.0  44.2529  -85.0170    1126.0      Furniture designer
#
#       unix_time  merch_lat  merch_long  is_fraud
# 0  1.371817e+09  33.986391  -81.200714       0.0
# 1  1.371817e+09  39.450498 -109.960431       0.0
# 2  1.371817e+09  40.495810  -74.196111       0.0
# 3  1.371817e+09  28.812398  -80.883061       0.0
# 4  1.371817e+09  44.959148  -85.884734       0.0

# %%
train_data['merchant'].value_counts()
# Out:
# fraud_Kilback LLC                        970
# fraud_Schumm PLC                         837
# fraud_Dickinson Ltd                      829
# fraud_Cormier LLC                        802
# fraud_Boyer PLC                          782
#                                         ...
# fraud_Larson, Quitzon and Spencer        168
# fraud_Ankunding-Carroll                  164
# fraud_McLaughlin, Armstrong and Koepp    164
# fraud_Schroeder, Wolff and Hermiston     163
# fraud_Ritchie, Bradtke and Stiedemann    156
# Name: merchant, Length: 693, dtype: int64

# %%
encoder = LabelEncoder()
train_data["merchant"] = encoder.fit_transform(train_data["merchant"])
train_data["category"] = encoder.fit_transform(train_data["category"])
train_data["gender"] = encoder.fit_transform(train_data["gender"])
train_data["job"] = encoder.fit_transform(train_data["job"])
train_data["state"] = encoder.fit_transform(train_data["state"])

test_data["merchant"] = encoder.fit_transform(test_data["merchant"])
test_data["category"] = encoder.fit_transform(test_data["category"])
test_data["gender"] = encoder.fit_transform(test_data["gender"])
test_data["job"] = encoder.fit_transform(test_data["job"])
test_data["state"] = encoder.fit_transform(test_data["state"])
train_data.head()
# Out:
#              cc_num  merchant  category  gender  state      zip      lat  \
# 0  2291163933867244       319        10       1     39  29209.0  33.9659
# 1  3573030041201292       591        10       0     43  84002.0  40.3207
# 2  3598215285024754       611         5       0     33  11710.0  40.6729
# 3  3591919803438423       222         9       1      8  32780.0  28.5697
# 4  3526826139003047       292        13       1     21  49632.0  44.2529
#
#        long  city_pop  job     unix_time  merch_lat  merch_long  is_fraud
# 0  -80.9355  333497.0  275  1.371817e+09  33.986391  -81.200714       0.0
# 1 -110.4360     302.0  392  1.371817e+09  39.450498 -109.960431       0.0
# 2  -73.5365   34496.0  259  1.371817e+09  40.495810  -74.196111       0.0
# 3  -80.8191   54767.0  407  1.371817e+09  28.812398  -80.883061       0.0
# 4  -85.0170    1126.0  196  1.371817e+09  44.959148  -85.884734       0.0

# %%
X = train_data.drop(['is_fraud'], axis=1)
y = train_data['is_fraud']
X1 = test_data.drop(['is_fraud'], axis=1)
y1 = test_data['is_fraud']

# %%
X.dropna(inplace=True)
y.dropna(inplace=True)
X1.dropna(inplace=True)
y1.dropna(inplace=True)

# %%
X.isnull().sum()
# Out:
# cc_num        0
# merchant      0
# category      0
# gender        0
# state         0
# zip           0
# lat           0
# long          0
# city_pop      0
# job           0
# unix_time     0
# merch_lat     0
# merch_long    0
# dtype: int64

# %%
y.isnull().sum()
# Out:
# 0

# %%
X1.isnull().sum()
# Out:
# cc_num        0
# merchant      0
# category      0
# gender        0
# state         0
# zip           0
# lat           0
# long          0
# city_pop      0
# job           0
# unix_time     0
# merch_lat     0
# merch_long    0
# dtype: int64

# %%
y1.isnull().sum()
# Out:
# 0

# %%
clf = GridSearchCV(LogisticRegression(solver='liblinear', multi_class='auto'), {
    'C': [1,10,20],
}, cv=5, return_train_score=False)
clf.fit(X, y)
clf.cv_results_
train_data1 = pd.DataFrame(clf.cv_results_)
train_data1
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.623894      0.021572         0.015974        0.000474       1
# 1       0.619793      0.018398         0.015828        0.000470      10
# 2       0.783600      0.085716         0.031699        0.004850      20
#
#       params  split0_test_score  split1_test_score  split2_test_score  \
# 0   {'C': 1}           0.995393           0.995393           0.995393
# 1  {'C': 10}           0.995393           0.995393           0.995393
# 2  {'C': 20}           0.995393           0.995393           0.995393
#
#    split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0           0.995393           0.995393         0.995393    3.879894e-08
# 1           0.995393           0.995393         0.995393    3.879894e-08
# 2           0.995393           0.995393         0.995393    3.879894e-08
#
#    rank_test_score
# 0                1
# 1                1
# 2                1

# %%
from sklearn.metrics import accuracy_score
Model1=LogisticRegression(solver='liblinear', multi_class='auto',C=10)
Model1.fit(X, y)
y_pred = Model1.predict(X1)
accuracy = accuracy_score(y1, y_pred)
print("Accuracy:", accuracy)
score=[]
score.append(accuracy)
score
# Out:
# Accuracy: 0.995392925045641
# [0.995392925045641]

# %%
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
print("Shape of X:", X1.shape)
print("Shape of y:", y1.shape)
# Out:
# Shape of X: (290857, 13)
# Shape of y: (290857,)
# Shape of X: (290857, 13)
# Shape of y: (290857,)

# %%
rs = RandomForestClassifier()
rs.fit(X,y)
y_pred = rs.predict(X1)
accuracy = accuracy_score(y1, y_pred)
print("Accuracy:", accuracy)
score.append(accuracy)
score
# Out:
# Accuracy: 1.0
# [0.995392925045641, 1.0]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np
rs = RandomForestClassifier()
rs.fit(X, y)
y_pred = rs.predict(X1)
accuracy = accuracy_score(y1, y_pred)
print("Accuracy:", accuracy)
score[1]=0.9938982397285364
score
# Out:
# Accuracy: 1.0
# [0.995392925045641, 0.9938982397285364]

# %%
clf = GridSearchCV(tree.DecisionTreeClassifier(random_state=0), {
            'criterion': ['gini', 'entropy']
,
}, cv=10, return_train_score=False)
clf.fit(X, y)
clf.cv_results_
train_data3 = pd.DataFrame(clf.cv_results_)
train_data3
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       5.278462      1.140806         0.011628        0.002555
# 1       3.944081      0.498844         0.010595        0.001415
#
#   param_criterion                    params  split0_test_score  \
# 0            gini     {'criterion': 'gini'}           0.989651
# 1         entropy  {'criterion': 'entropy'}           0.993227
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.972392           0.990064           0.991852           0.956886
# 1           0.992643           0.990373           0.986798           0.977515
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0           0.975280           0.992608           0.970638           0.960358
# 1           0.976518           0.918793           0.928795           0.975142
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.00471         0.880444        0.292174                1
# 1            0.00471         0.874451        0.290978                2

# %%
Dtree=tree.DecisionTreeClassifier(random_state=0,criterion='entropy',splitter="best")
Dtree.fit(X, y)
y_pred = Dtree.predict(X1)
accuracy = accuracy_score(y1, y_pred)
print("Accuracy:", accuracy)
score.append(accuracy)

# %%
plt.rcParams["figure.figsize"] = (20,15)

# %%
import matplotlib.pyplot as plt
import numpy as np

Models = ['LogisticRegression', 'RandomForest', 'DecisionTree']
y = score

fig, ax = plt.subplots()

x = np.arange(len(Models))

ax.bar(x, y, width=0.2)
ax.set_xticks(x)
ax.set_xticklabels(Models)
ax.set_xlabel('Models')
ax.set_ylabel('Score')
ax.set_ylim(0, 1.0)  # Adjust the y-axis limit based on your data range

for index, value in enumerate(y):
    plt.text(x=index, y=value+0.01 , s=str(round(value, 5)), ha='center')

plt.tight_layout()
plt.show()
